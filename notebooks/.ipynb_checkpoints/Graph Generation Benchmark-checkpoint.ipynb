# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Benchmarking Graph Generation
# ### 1.1 Sparse Graphs
# #### Loading Results

# %%
sparse_benchmark=pd.read_csv("/run/media/ramizouari/INTENSO/MPG/benchmark_gnp_random_mpg_sparse.csv")
sparse_benchmark.sample(10)
# Out:
#          n  c         p             execution_start  \
# 2866  3481  3  0.000862  2023-03-09 11:57:14.913497
# 1209   676  1  0.001479  2023-03-09 11:53:34.753378
# 2202  2116  1  0.000473  2023-03-09 11:55:05.762103
# 1735  1296  7  0.005401  2023-03-09 11:54:09.703397
# 4324  7744  5  0.000646  2023-03-09 12:06:40.316217
# 2090  1849  9  0.004867  2023-03-09 11:54:49.404042
# 3572  5329  5  0.000938  2023-03-09 12:00:53.529695
# 3255  4489  1  0.000223  2023-03-09 11:59:05.475996
# 4344  7744  9  0.001162  2023-03-09 12:06:53.690810
# 3216  4356  3  0.000689  2023-03-09 11:58:52.110768
#
#                    execution_end      time  nodes  edges    distribution  \
# 2866  2023-03-09 11:57:15.013044  0.099547   3481  10937  integers(-1,1)
# 1209  2023-03-09 11:53:34.772044  0.018665    676   1067  integers(-1,1)
# 2202  2023-03-09 11:55:05.886935  0.124832   2116   3312  integers(-1,1)
# 1735  2023-03-09 11:54:09.765007  0.061609   1296   8958  integers(-1,1)
# ...

# %% [markdown]
# #### Plotting Results

# %%
fig,ax=plt.subplots()
sns.lineplot(data=sparse_benchmark,x="nodes",y="time",hue="c",ax=ax)
ax.set_title("Generation Time as a function of number of nodes")
# Out:
# Text(0.5, 1.0, 'Generation Time as a function of number of nodes')

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 1.2 Dense Graphs
# #### Loading Results

# %%
dense_benchmark=pd.read_csv("/run/media/ramizouari/INTENSO/MPG/benchmark_gnp_random_mpg_dense.csv")
dense_benchmark.sample(10)
# Out:
#         n    c     p             execution_start               execution_end  \
# 2028  900  900  1.00  2023-03-13 12:10:05.489173  2023-03-13 12:10:10.395183
# 383    49   10  0.20  2023-03-13 11:46:28.897849  2023-03-13 11:46:28.900715
# 638   121    1  0.01  2023-03-13 11:46:34.388265  2023-03-13 11:46:34.391538
# 1269  400    4  0.01  2023-03-13 11:49:00.936980  2023-03-13 11:49:00.950121
# 1322  400  400  1.00  2023-03-13 11:49:31.349418  2023-03-13 11:49:32.091460
# 88      9    0  0.05  2023-03-13 11:46:28.042986  2023-03-13 11:46:28.043405
# 1781  729  146  0.20  2023-03-13 11:58:27.741015  2023-03-13 11:58:28.243079
# 1737  676  541  0.80  2023-03-13 11:57:20.814681  2023-03-13 11:57:22.457934
# 1438  484   97  0.20  2023-03-13 11:50:45.817406  2023-03-13 11:50:46.042550
# 792   169   17  0.10  2023-03-13 11:46:43.870419  2023-03-13 11:46:43.886448
#
#           time  nodes   edges    distribution                   filename
# ...

# %% [markdown]
# #### Plotting Results

# %%
fig,ax=plt.subplots()
sns.lineplot(data=dense_benchmark,x="nodes",y="time",hue="p",ax=ax,legend="full")
ax.set_title("Generation Time as a function of number of nodes")
# Out:
# Text(0.5, 1.0, 'Generation Time as a function of number of nodes')

# %% [markdown]
# #### Analysis

# %% [markdown]
# ## 2. Benchmarking Optimal Strategy Resolution
# ### 2.1 Visualising Execution

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import visualisation.game as vgame
import pickle
import games.mpg as mpg
import networkx as nx
import mpgio
graph=mpgio.read_mpg("/run/media/ramizouari/INTENSO/MPG/dataset/sparse/gnp_uniform_mpg_25_1_2.edgelist.gz",nodetype=int,edgetype=int)
fig,ax=plt.subplots()
visual_graph=vgame.MPGPlot(graph)
S1,S2=mpg.optimal_strategy_pair(graph)
visual_graph.set_node_color_mapping(vgame.WinnerVisualiser(graph,S1,S2))
visual_graph.set_edge_color_mapping(vgame.StrategyVisualiser(S1,S2))
visual_graph.plot(ax)
# Out:
# <Axes: >

# %%
graph=mpgio.read_mpg("/run/media/ramizouari/INTENSO/MPG/dataset/dense/gnp_uniform_mpg_225_225_0.edgelist.gz",nodetype=int,edgetype=int)
S1,S2=mpg.optimal_strategy_pair(graph)

# %%
import os
import re
import numpy as np
base_dir="/run/media/ramizouari/INTENSO/MPG/"
directory="/run/media/ramizouari/INTENSO/MPG/dataset"
for file in os.listdir(directory):
    match=re.search(R"gnp_uniform_mpg_(\d+)_(\d+)_(\d+)(\.edgelist\.gz)",file)
    if match:
        n=int(match.group(1))
        extension=match.group(4)
    if n <=36:
        graph=nx.read_weighted_edgelist(os.path.join(directory,file),create_using=mpg.MeanPayoffGraph,nodetype=int)
        for e in graph.edges:
            for u in graph.edges[e]:
                graph.edges[e][u]=int(graph.edges[e][u])
        fig,ax=plt.subplots()
        visual_graph=vgame.MPGPlot(graph)
        S1,S2=mpg.optimal_strategy_pair(graph)
        visual_graph.set_node_color_mapping(vgame.WinnerVisualiser(graph,S1,S2))
        visual_graph.set_edge_color_mapping(vgame.StrategyVisualiser(S1,S2))
        visual_graph.plot(ax)
        fig.savefig(os.path.join(base_dir,"img",file.replace(match.group(4),".png")))
        plt.close(fig)

# %%
graph.edges[(0,1)]["weight"]
# Out:
# 0.0

# %% [markdown]
# ### 2.2 Sparse Graphs
# #### Executing Sparse Graphs

# %%
import os
from datetime import time,datetime,date
import timeit
import numpy as np
import pandas as pd
import re
timelimit=10
tolerance=5
TLE={}
dataset=[]
directory="/run/media/ramizouari/INTENSO/MPG/dataset/sparse"
for file in os.listdir(directory):
    match=re.search(R"gnp_uniform_mpg_(\d+)_(\d+)_(\d+)(\.edgelist\.gz)",file)
    if match:
        n=int(match.group(1))
        c=int(match.group(2))
        if c not in TLE:
            TLE[c]=0
        extension=match.group(4)
    else:
        continue
    if TLE[c] > tolerance:
        continue
    row={}
    row["filename"]=file
    row["nodes"]=n
    row["n"]=n
    row["c"]=c
    graph=nx.read_weighted_edgelist(os.path.join(directory,file),create_using=mpg.MeanPayoffGraph,nodetype=int)
    for e in graph.edges:
                for u in graph.edges[e]:
                    graph.edges[e][u]=graph.edges[e][u]
    start=timeit.default_timer()
    mpg.optimal_strategy_pair(graph)
    end=timeit.default_timer()
    dt=end-start
    if dt > timelimit:
        TLE[c]+=1
    row["time"]=end-start
    dataset.append(row)
    
dataset=pd.DataFrame(dataset)

# %% [markdown]
# #### Saving Results

# %%
dataset.to_csv("execution_time_sparse.csv")

# %% [markdown]
# #### Plotting Running Time

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig,ax=plt.subplots(figsize=(13,8))
S=dataset.groupby(["n","c"]).max()["time"]
dataset["maxtime"]=[S[s["n"],s["c"]]  for s in dataset.iloc]
sns.lineplot(data=dataset,x="n",y="maxtime",hue="c",ax=ax)
ax.set_title("Worst running time with respect to graph size")
fig.savefig("running_time.png")

# %% [markdown]
# #### Linear regression: $\ln(T)=\alpha \ln n+\beta$

# %%
from sklearn import linear_model
regression={}
for c in dataset["c"].unique():
    D=dataset[dataset["c"]==c]
    regression[c]=linear_model.LinearRegression()
    X_log=np.log(D["nodes"]).to_numpy().reshape(-1,1)
    y_log=np.log(D["maxtime"])
    regression[c].fit(X_log,y_log)

# %% [markdown]
# #### Estimating Growth order

# %%
{c: regression[c].coef_ for c in dataset["c"].unique()}
# Out:
# {1: array([1.91501248]),
#  3: array([1.88234909]),
#  5: array([1.93400774]),
#  7: array([2.24053911]),
#  9: array([1.943817])}

# %% [markdown]
# #### Estimating Constant Factor

# %%
{c: np.exp(regression[c].intercept_) for c in dataset["c"].unique()}
# Out:
# {1: 0.00013440219176678728,
#  3: 0.0005283879059902485,
#  5: 0.0009415638111394152,
#  7: 0.00044085821805409054,
#  9: 0.001791263585169673}

# %% [markdown]
# #### Fitting Quadratic Regression

# %%
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

fig,ax=plt.subplots(figsize=(13,8))
S=dataset.groupby(["n","c"]).max()["time"]
dataset["maxtime"]=[S[s["n"],s["c"]]  for s in dataset.iloc]

quadratic_model={}
model_data=[]
N=np.arange(1,400).reshape((-1,1))
for c in dataset["c"].unique():
    D=dataset[dataset["c"]==c]
    quadratic_model[c]=Pipeline([("quadratic_features",PolynomialFeatures(degree=2)),("linear_regression",linear_model.LinearRegression())])
    X=D["nodes"].to_numpy().reshape(-1,1)
    y=D["maxtime"]
    quadratic_model[c].fit(X,y)
    for n,t in zip(N.flatten(),quadratic_model[c].predict(N).flatten()):
        model_data.append({"c":c,"n":n,"maxtime":t})
model_data=pd.DataFrame(model_data)
model_data["type"]="prediction"
dataset["type"]="observation"
cum_data=pd.concat([model_data,dataset],ignore_index=True)
sns.lineplot(data=cum_data[cum_data["maxtime"]<50],x="n",y="maxtime",hue="c",ax=ax,style="type",style_order=("observation","prediction"),color="black")
ax.set_title("Worst case running time as a function of the graph size")
fig.savefig("results.png")
